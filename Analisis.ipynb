# %%
import glob
from bs4 import BeautifulSoup
import os
import time
import datetime
import pandas as pd
import numpy as np
import bz2
import plotly.express as px
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # descomprimir Archivos

# %% [markdown]
# f_in = open("DataSui_ele_com_096.csv.gz", "rb")
# f_out = open("DataSui_ele_com_096.csv", "wb")
# f_out.write(bz2.decompress(f_in.read()))
# f_out.close()
# f_in.close()

# %%
FinalM = pd.read_csv(
    "./DataSui_ele_com_096.csv",      # relative python path to subdirectory
    sep=',',           # Tab-separated value file.
    #quotechar="'",        # single quote allowed as quote character
    #dtype={"salary": int},             # Parse the salary column as an integer 
    #usecols=['name', 'birth_date', 'salary'].   # Only load the three columns specified.
    #parse_dates=['birth_date'],     # Intepret the birth_date column as a date
    #skiprows=10,         # Skip the first 10 rows of the file
    na_values=''      # Take any '.' or '??' values as NA
)

# %%
#Funciones
def ReplaceList(listOri,strRep,strOri="_Suscriptores"):
    b=[]
    for i in listOri:
        b.append(i.replace(strOri,strRep ))
    return b
def GraficoBarra(Tabla,Clases,Indice,titulo,aggF=np.sum,div=12):
    table = pd.pivot_table(Tabla, values=Clases, index=Indice,aggfunc=aggF)/div
    grafica=px.bar(table, x=table.index, y=Clases, title=titulo)
    return grafica
def ValorPorPersona(Tabla,ColumnaPatron,PatronColumnaA, PatronColumnaB, PatronResultado):
    for i in ColumnaPatron:
        ii=i.replace(PatronColumnaA,PatronColumnaB)
        iii=i.replace(PatronColumnaA,PatronResultado)
        Tabla[iii]=Tabla[ii]/Tabla[i]
    return Tabla
def PrecioKilovatio(Tabla,ColumnaPatron,PatronColumnaA, PatronColumnaB, PatronResultado):
    for i in ColumnaPatron:
        ii=i.replace(PatronColumnaA,PatronColumnaB)
        iii=i.replace(PatronColumnaA,PatronResultado)
        Tabla[iii]=Tabla[ii]/Tabla[i]
    return Tabla

# %%
# Enriqueser datos
ClasesSuscriptores=["Estrato 1_Suscriptores","Estrato 2_Suscriptores", "Estrato 3_Suscriptores", "Estrato 4_Suscriptores", "Estrato 5_Suscriptores", "Estrato 6_Suscriptores", "Industrial_Suscriptores", "Comercial_Suscriptores", "Oficial_Suscriptores", "Otros_Suscriptores"]
ClasesConsumo=ReplaceList(ClasesSuscriptores,"_Consumo")
ClasesValor=ReplaceList(ClasesSuscriptores,"_Valor Consumo")
ClasesConsumoPorSus=ReplaceList(ClasesSuscriptores,"_Consumo Por Suscritor")
ClasesValorPorSus=ReplaceList(ClasesSuscriptores,"_Valor Por Suscritor")
ClasesPrecioPorWat=ReplaceList(ClasesSuscriptores,"_Precio por Vatio")


F=ValorPorPersona(FinalM,ClasesSuscriptores,"_Suscriptores","_Consumo","_Consumo Por Suscritor")
F=ValorPorPersona(F,ClasesSuscriptores,"_Suscriptores","_Valor Consumo","_Valor Por Suscritor")
F=PrecioKilovatio(F,ClasesConsumoPorSus,"_Consumo Por Suscritor","_Valor Por Suscritor","_Precio por Vatio")

# %%
F
# Out:
#         Unnamed: 0   Age  Month    Site     Departamento  \
# 0                0  2016  Julio  Urbano           NARINO
# 1                1  2016  Julio  Urbano           NARINO
# 2                2  2016  Julio  Urbano           NARINO
# 3                3  2016  Julio  Urbano           NARINO
# 4                4  2016  Julio  Urbano           NARINO
# ...            ...   ...    ...     ...              ...
# 626471        1003  2012  Abril   Rural  VALLE DEL CAUCA
# 626472        1004  2012  Abril   Rural        ATLANTICO
# 626473        1005  2012  Abril   Rural        SANTANDER
# 626474        1006  2012  Abril   Rural           TOLIMA
# 626475        1007  2012  Abril   Rural        ANTIOQUIA
#
#                    Municipio                                    Empresa  \
# 0                 YACUANQUER  A.S.C INGENIERIA SOCIEDAD ANONIMA SA ESP.
# 1                     TANGUA  A.S.C INGENIERIA SOCIEDAD ANONIMA SA ESP.
# ...

# %%
FinalM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626476 entries, 0 to 626475
# Data columns (total 67 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        626476 non-null  int64
#  1   Age                               626476 non-null  int64
#  2   Month                             626476 non-null  object
#  3   Site                              626476 non-null  object
#  4   Departamento                      626476 non-null  object
#  5   Municipio                         626476 non-null  object
#  6   Empresa                           626476 non-null  object
#  7   Estrato 1_Suscriptores            376131 non-null  float64
#  8   Estrato 2_Suscriptores            370945 non-null  float64
#  9   Estrato 3_Suscriptores            287641 non-null  float64
#  10  Estrato 4_Suscriptores            143353 non-null  float64
# ...

# %%
grafica_0= GraficoBarra(FinalM,ClasesSuscriptores,['Age'],"Suscriptores anuales promedios")
grafica_0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-46755b484687> in <module>
# ----> 1 grafica_0= GraficoBarra(FinalM,ClasesSuscriptores,['Age',"Month"],"Suscriptores anuales promedios")
#       2 grafica_0
#
# <ipython-input-7-4f7f55839af4> in GraficoBarra(Tabla, Clases, Indice, titulo, aggF, div)
#       7 def GraficoBarra(Tabla,Clases,Indice,titulo,aggF=np.sum,div=12):
#       8     table = pd.pivot_table(Tabla, values=Clases, index=Indice,aggfunc=aggF)/div
# ----> 9     grafica=px.bar(table, x=table.index, y=Clases, title=titulo)
#      10     return grafica
#      11 def ValorPorPersona(Tabla,ColumnaPatron,PatronColumnaA, PatronColumnaB, PatronResultado):
#
# ...

# %%
grafica_0= GraficoBarra(FinalM,ClasesConsumo,['Age'],"Consumo Mensual")
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesValor,['Age'],"Valor en Pesos Mensual")
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesConsumoPorSus,['Age'],"Consumo Por Suscriptor",aggF=np.median)
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesValorPorSus,['Age'],"Valor Por Suscriptor",aggF=np.median)
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesPrecioPorWat,['Age'],"Precio Por KW",aggF=np.median,div=1)
grafica_0

# %%
FinalGuacari = FinalM[FinalM['Municipio'] == "GUACARI"]

# %%
FinalGuacari.to_csv(path_or_buf="./DataSui_ele_com_096_Guacari.csv", sep=',', na_rep='',header=True, index=True, decimal='.')

# %%
FinalGuacari
# Out:
#         Unnamed: 0   Age       Month    Site     Departamento Municipio  \
# 1856          1856  2016       Julio  Urbano  VALLE DEL CAUCA   GUACARI
# 3026          1016  2014       Julio   Rural  VALLE DEL CAUCA   GUACARI
# 3550           432  2017       Marzo  Urbano  VALLE DEL CAUCA   GUACARI
# 4986          1868  2017       Marzo  Urbano  VALLE DEL CAUCA   GUACARI
# 5542           447  2018  Septiembre  Urbano  VALLE DEL CAUCA   GUACARI
# ...            ...   ...         ...     ...              ...       ...
# 623719        1094  2010   Diciembre  Urbano  VALLE DEL CAUCA   GUACARI
# 625439        1132  2007  Septiembre   Rural  VALLE DEL CAUCA   GUACARI
# 626167         699  2012       Abril   Rural  VALLE DEL CAUCA   GUACARI
# 626428         960  2012       Abril   Rural  VALLE DEL CAUCA   GUACARI
# 626471        1003  2012       Abril   Rural  VALLE DEL CAUCA   GUACARI
#
#                                                   Empresa  \
# ...

# %%
grafica_0= GraficoBarra(FinalGuacari,ClasesSuscriptores,['Age'],"Suscriptores anuales promedios de Guacari")
grafica_0

# %%
grafica_0= GraficoBarra(FinalGuacari,ClasesConsumo,['Age'],"Consumo Mensual Guacari")
grafica_0

# %%
grafica_0= GraficoBarra(FinalGuacari,ClasesValor,['Age'],"Valor en Pesos Mensual")
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesConsumoPorSus,['Age'],"Consumo Por Suscriptor",aggF=np.median)
grafica_0

# %%
grafica_0= GraficoBarra(FinalM,ClasesValorPorSus,['Age'],"Valor Por Suscriptor",aggF=np.median)
grafica_0

# %%
grafica_1= GraficoBarra(FinalGuacari,ClasesPrecioPorWat,['Age'],"Precio Por KW",aggF=np.median,div=1)
grafica_1

# %%
FinalGuacari.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 1856 to 626471
# Data columns (total 67 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        847 non-null    int64
#  1   Age                               847 non-null    int64
#  2   Month                             847 non-null    object
#  3   Site                              847 non-null    object
#  4   Departamento                      847 non-null    object
#  5   Municipio                         847 non-null    object
#  6   Empresa                           847 non-null    object
#  7   Estrato 1_Suscriptores            283 non-null    float64
#  8   Estrato 2_Suscriptores            283 non-null    float64
#  9   Estrato 3_Suscriptores            283 non-null    float64
#  10  Estrato 4_Suscriptores            43 non-null     float64
# ...

# %%
fig = px.treemap(FinalM, path=[ 'Departamento', 'Municipio',"Site", "Empresa"], values='Estrato 1_Suscriptores')
fig

# %%
px.data.gapminder().query("year == 2007")
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...
